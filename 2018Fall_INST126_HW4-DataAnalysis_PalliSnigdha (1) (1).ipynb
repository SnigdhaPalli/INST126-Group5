# %% [markdown]
# # INST 126 - Homework 4
# ## Fall 2018
#
#
# ## Due: Friday, 11/15, as posted on ELMS
#
# **Submission** Submit this downloaded completed Jupyter notebook file (.ipynb) in the assignment on ELMS. Make sure when you save that you have *run all* cells in this notebook so the outputs display between the cells.
# <br>
# **Notes**
# Save your work early and often. Make backup copies, too. You don’t want to lose your work if the server goes down even though the notebook saves periodically. <br>
#
# Replace "LastNameFirstName" in the file name with your last name and first name. <br>
# <br>
# *Double Click to edit this cell - then run the cell to return to plain text.* <br>
# <br>
# Name: Snigdha Palli<br>
# Date: 11/10/18<br>
# Email: snigdha@samirpalli.com<br>
#
# In this assignment you will use Pandas to clean up and do some basic analysis of two data sets. The first set of questions (about California schools test scores) guide you through the process step by step. In the latter part you will apply and extend your skills without the step-by-step instructions, by answering questions about the occupational data from the Bureau of Labor Statistics(BLS).
#
# The "Caschool.csv" data set contains data about test scores in California schools during the 1998-1999 school year. The dataframe provides information such as the county, school district, grade span of district, number of teachers, percent who qualify for reduced price lunch, number of computers per school district, average test scores, student teacher ratio, average reading score, and the average math score. To learn more about the dataset, see https://vincentarelbundock.github.io/Rdatasets/doc/Ecdat/Caschool.html.

# %% [markdown]
# ### Question 1 (2 pts):  Read the data into a data frame, then clean up the data by removing the "Unamed" column from the dataframe.

# %%
# Your code goes here
import pandas as pd
school_df = pd.read_csv("Caschool.csv")
school_remove = school_df.drop(columns = "Unnamed: 0")
print(school_remove)
# Out:
#      distcod         county                         district grspan  enrltot  \
# 0      75119        Alameda               Sunol Glen Unified  KK-08      195
# 1      61499          Butte             Manzanita Elementary  KK-08      240
# 2      61549          Butte      Thermalito Union Elementary  KK-08     1550
# 3      61457          Butte  Golden Feather Union Elementary  KK-08      243
# 4      61523          Butte         Palermo Union Elementary  KK-08     1335
# 5      62042         Fresno          Burrel Union Elementary  KK-08      137
# 6      68536    San Joaquin            Holt Union Elementary  KK-08      195
# 7      63834           Kern              Vineland Elementary  KK-08      888
# 8      62331         Fresno         Orange Center Elementary  KK-08      379
# 9      67306     Sacramento      Del Paso Heights Elementary  KK-06     2247
# 10     65722         Merced        Le Grand Union Elementary  KK-08      446
# ...

# %% [markdown]
# ### Question 2 (4 pts total)
# #### Part 1 (2 pts): Find the following information **without** using the `describe` method:
# * Average test score in California schools
# * Highest test score in California schools
# * Lowest test score in California schools
# * Median number of computers in California schools
# * Highest number of teachers in California schools
# * Lowest number of teachers in California schools
#
# Your output should look like this:
# <br> `Average test score in California schools:  654.156548055013`
# <br> `Highest test score in California schools:  706.75`
# <br> `Lowest test score in California schools:   605.550048828`
# <br> `Median number of computers per student in CA schools: 117.5 `
# <br> `Highest number of teachers in CA schools:  1429.0 `
# <br> `Lowest number of teachers in CA schools:  4.8499999046325`

# %%
# Average test score in California schools
school_avg = school_remove["testscr"].mean()
print("Average test score in California schools: %f" % (school_avg))

# Highest test score in California schools
school_highest = school_remove["testscr"].max()
print("Highest test score in California schools: %g" % (school_highest))

# Lowest test score in California schools
school_lowest = school_remove["testscr"].min()
print("Lowest test score in California schools: %f" % (school_lowest))

# Median number of computers in California schools
school_median = school_remove["computer"].median()
print("Median number of computers per student in CA schools: %g" % (school_median))

# Highest number of teachers in California schools
teachers_highest = school_remove["teachers"].max()
print("Highest number of teachers in CA schools: %g" % (teachers_highest))

# Lowest number of teachers in California schools
teachers_lowest = school_remove["teachers"].min()
print("Highest number of teachers in CA schools: %f" % (teachers_lowest))
# Out:
# Average test score in California schools: 654.156548
# Highest test score in California schools: 706.75
# Lowest test score in California schools: 605.550049
# Median number of computers per student in CA schools: 117.5
# Highest number of teachers in CA schools: 1429
# Highest number of teachers in CA schools: 4.850000

# %% [markdown]
# #### Part 2 (2 pts): Determine whether the school district with the highest test score also has the highest number of teachers.
#
# First, use the `df.loc` method to find and print out the row in the dataframe where the test score equals the highest test score in the dataset (which you determined in part 1 of this question).

# %%
# Your code goes here
school_remove.loc[school_remove['testscr'] == (school_highest)]
# Out:
#      distcod       county              district grspan  enrltot    teachers  \
# 416    69518  Santa Clara  Los Altos Elementary  KK-08     3724  208.479996
#
#      calwpct  mealpct  computer  testscr   compstu      expnstu        str  \
# 416   1.0741   1.5038       721   706.75  0.193609  5741.462891  17.862625
#
#         avginc     elpct  readscr  mathscr
# 416  41.734108  4.726101    704.0    709.5

# %% [markdown]
# Second, use the `df.loc` method to find and print out the row in the dataframe where the number of teachers is equal to the highest number of teachers in the dataset (which you also determined in part 1 of this question).

# %%
# Your code goes here
school_remove.loc[school_remove['teachers'] == (teachers_highest)]
# Out:
#     distcod county                     district grspan  enrltot  teachers  \
# 48    63321   Kern  Bakersfield City Elementary  KK-08    27176    1429.0
#
#       calwpct    mealpct  computer     testscr   compstu      expnstu  \
# 48  39.218399  84.294998      3324  630.549988  0.122314  5864.366211
#
#           str     avginc      elpct     readscr  mathscr
# 48  19.017494  12.109128  28.863705  631.599976    629.5

# %% [markdown]
# Are they the same school district?

# %%
# They are not in the same school disctrict.

# %% [markdown]
# ### Question 3 (6 pts total)
# #### Part 1 (2 pt): Which five counties have the most schools in California?
#
# Your output should look like this:
#
# <br> `Sonoma         29`
# <br> `Kern           27`
# <br> `Los Angeles    27`
# <br> `Tulare         24`
# <br> `San Diego      21`
#
# *Hint: is there a pandas function that can give you this answer for a given column?*

# %%
# Your code goes here

most_counties = school_remove['county'].value_counts()
most_counties.head()
# Out:
# Sonoma         29
# Kern           27
# Los Angeles    27
# Tulare         24
# San Diego      21
# Name: county, dtype: int64

# %% [markdown]
# #### Part 2 (2 pt):  Group the counties by the "county" column, summarized by the mean of the values for each of the other columns
# Store the resulting grouped dataframe in the variable `group_county` and display the grouped dataframe.

# %%
# Your code goes here.
group_county = school_remove.groupby(by = 'county').mean()
print(group_county)
# Out:
#                       distcod      enrltot    teachers    calwpct    mealpct  \
# county
# Alameda          75119.000000   195.000000   10.900000   0.510200   2.040800
# Butte            61486.166667  1152.500000   60.516667  36.265900  68.016234
# Calaveras        61572.000000   777.000000   36.849998  12.988700  39.848701
# Contra Costa     61737.714286  2725.857143  137.681428   3.506171  13.534900
# El Dorado        61912.500000  1372.900000   69.485000   6.725630  22.605750
# Fresno           62250.083333   504.416667   26.369167  21.084200  74.445959
# Glenn            62596.000000   137.666667    6.583333   7.108700  46.848766
# Humboldt         62887.647059   379.705882   20.598235  17.813129  43.814188
# Imperial         63162.666667  1936.000000   92.453335  19.743500  63.473366
# Inyo             63255.000000  1510.000000   73.300003  10.259800  37.108601
# Kern             63929.407407  3108.333333  157.319352  18.366489  64.325852
# ...

# %% [markdown]
# #### Part 3 (2 pt): Continue using the new grouped dataframe. Which counties have an average reading score higher than 650?
#
# In the example output below, only the first 15 rows are shown but your output should display all 45 rows.
#
# <br> Your output should look like this:
# <br> `county`
# <br> `Alameda            True`
# <br> `Butte              False`
# <br> `Calaveras          True`
# <br> `Contra Costa       True`
# <br> `El Dorado          True`
# <br> `Fresno             False`
# <br> `Glenn              True`
# <br> `Humboldt           True`
# <br> `Imperial           False`
# <br> `Inyo               True`
# <br> `Kern               False`
# <br> `Kings              False`
# <br> `Lake               False`
# <br> `Lassen             True`
# <br> `Los Angeles        False`
#
# <br> In the example output above, only the first 15 rows are shown but your output should display all 45 rows.

# %%
group_county['readscr'] > 650
# Out:
# county
# Alameda             True
# Butte              False
# Calaveras           True
# Contra Costa        True
# El Dorado           True
# Fresno             False
# Glenn               True
# Humboldt            True
# Imperial           False
# Inyo                True
# Kern               False
# Kings              False
# Lake               False
# Lassen              True
# Los Angeles        False
# Madera              True
# Marin               True
# Mendocino          False
# Merced             False
# Monterey           False
# Nevada              True
# Orange              True
# Placer              True
# Riverside          False
# Sacramento         False
# San Benito         False
# San Bernardino     False
# San Diego           True
# San Joaquin        False
# San Luis Obispo     True
# San Mateo           True
# Santa Barbara       True
# Santa Clara         True
# Santa Cruz          True
# Shasta              True
# Siskiyou            True
# ...

# %% [markdown]
# ### Question 4 (8 pts total): Male and female income by occupation.
#
# The dataset "bls.csv" contains the median weekly earnings of full-time wage and salary workers by detailed occupation and sex. The data is structured as comma-separated values (CSV). Each row has seven fields:
#
# - Occupation: Job title as given from BLS. Industry summaries are given in ALL CAPS.
# - All_workers: Number of workers male and female, in thousands.
# - All_weekly: Median weekly income including male and female workers, in USD.
# - M_workers: Number of male workers, in thousands.
# - M_weekly: Median weekly income for male workers, in USD.
# - F_workers: Number of female workers, in thousands.
# - F_weekly: Median weekly income for female workers, in USD.
#
# #### Part 1 (2 pts): Create a new dataframe that contains only the ***industry*** data (i.e., excluding the rows that are about occupations) and assign it to the variable `industries`.
#
# ***Notes:***
# - In the Occupation column, ***industries*** are designated by upper case letters. ***Occupations*** (types of jobs) are mixed case. Use this distinction to help you answer subquestion a.
# - You may find the `df.loc` function helpful
# </pre>

# %%
# Your code here (you should end up with 23 rows in your dataframe)
bls_df = pd.read_csv("bls.csv")
industries = bls_df.loc[bls_df['Occupation'] == bls_df['Occupation'].str.upper()]
print(industries)
# Out:
#                   Occupation  All_workers All_weekly  M_workers M_weekly  \
# 0            ALL OCCUPATIONS       109080        809      60746      895
# 1                 MANAGEMENT        12480       1351       7332     1486
# 32                  BUSINESS         5942       1137       2686     1327
# 61             COMPUTATIONAL         4009       1428       3036     1503
# 78               ENGINEERING         2656       1424       2272     1452
# 100                  SCIENCE         1176       1206        662     1379
# 124           SOCIAL SERVICE         2143        889        776      973
# 133                    LEGAL         1346       1391        624     1877
# 139                EDUCATION         6884        956       1849     1144
# 151                     ARTS         1643       1001        930     1088
# 171  HEALTHCARE PROFESSIONAL         6566       1041       1639     1272
# 205       HEALTHCARE SUPPORT         2395        498        320      577
# ...

# %% [markdown]
# #### Part 2 (6 pts): Calculate wage statistics
#
# ***In separate cells below, calculate and print the indicated values (1 point each):***<pre>
# a. Using the `industries` dataframe, find the industries with the most and least *female* workers
# b. Using the `industries` dataframe, find the industries with the most and least *male* workers
# c. Using the `industries` dataframe, find the industries with less than 200 female workers
# d. Using the `industries` dataframe, compute the *average* income difference between male and females across industries
# e. Using the `industries` dataframe, find the industry that has the *largest* income difference between male and female workers
# f. Using the `industries` dataframe, find the industry that has the *smallest* income difference between male and female workers

# %%
# 2.a. Your code goes here
most_female = industries.loc[industries['F_workers'].idxmax()]
least_female = industries.loc[industries['F_workers'].idxmin()]
print(most_female)
print(least_female)
# Out:
# Occupation     ALL OCCUPATIONS
# All_workers             109080
# All_weekly                 809
# M_workers                60746
# M_weekly                   895
# F_workers                48334
# F_weekly                   726
# Name: 0, dtype: object
# Occupation     CONSTRUCTION
# All_workers            5722
# All_weekly              749
# M_workers              5586
# M_weekly                751
# F_workers               137
# F_weekly                704
# Name: 360, dtype: object

# %%
# 2.b. Your code goes here
most_male = industries.loc[industries['M_workers'].idxmax()]
least_male = industries.loc[industries['M_workers'].idxmin()]

print(most_male)
print(least_male)
# Out:
# Occupation     ALL OCCUPATIONS
# All_workers             109080
# All_weekly                 809
# M_workers                60746
# M_weekly                   895
# F_workers                48334
# F_weekly                   726
# Name: 0, dtype: object
# Occupation     HEALTHCARE SUPPORT
# All_workers                  2395
# All_weekly                    498
# M_workers                     320
# M_weekly                      577
# F_workers                    2074
# F_weekly                      490
# Name: 205, dtype: object

# %%
# 2.c. Your code goes here
industries.query('F_workers < 200')
# Out:
#        Occupation  All_workers All_weekly  M_workers M_weekly  F_workers  \
# 350  AGRICULTURAL          810        464        637      477        174
# 360  CONSTRUCTION         5722        749       5586      751        137
# 401   MAINTENANCE         4301        839       4159      842        143
#
#     F_weekly
# 350      437
# 360      704
# 401      761

# %%
# 2.d. Your code goes here
industries['F_weekly'] = industries['F_weekly'].astype(str).astype(float)
industries['M_weekly'] = industries['M_weekly'].astype(str).astype(float)

difference = industries['M_weekly'].mean() - industries['F_weekly'].mean() 

print(difference)
# Out:
# 200.86956521739125
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# 2.e. Your code goes here
industries['weekly_difference'] = industries['M_weekly'] - industries['F_weekly']
difference_max = industries['weekly_difference'].max()
print(difference_max)
final_max = industries.loc[industries['weekly_difference'] == difference_max]
print(final_max)
# Out:
# 742.0
#     Occupation  All_workers All_weekly  M_workers  M_weekly  F_workers  \
# 133      LEGAL         1346       1391        624    1877.0        722
#
#      F_weekly  weekly_difference
# 133    1135.0              742.0
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# 2.f. Your code goes here
industries['weekly_difference'] = industries['M_weekly'] - industries['F_weekly']
difference_min = industries['weekly_difference'].min()
print(difference_min)
final_min = industries.loc[industries['weekly_difference'] == difference_min]
print(final_min)
# Out:
# 40.0
#        Occupation  All_workers All_weekly  M_workers  M_weekly  F_workers  \
# 350  AGRICULTURAL          810        464        637     477.0        174
#
#      F_weekly  weekly_difference
# 350     437.0               40.0
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
